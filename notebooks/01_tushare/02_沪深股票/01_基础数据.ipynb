# %%
# 获取 Token
from configparser import ConfigParser
cfg = ConfigParser()
cfg.read('../config.ini')
token = cfg.get('tushare', 'token')
token

# 初始化 tushare
import tushare as ts
ts.set_token(token)
pro = ts.pro_api()

# %% [markdown]
# # 股票列表

# %%
df = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
df.head()
# Out:
#      ts_code  symbol  name area industry list_date
# 0  000001.SZ  000001  平安银行   深圳       银行  19910403
# 1  000002.SZ  000002   万科A   深圳     全国地产  19910129
# 2  000004.SZ  000004  国农科技   深圳     生物制药  19910114
# 3  000005.SZ  000005  世纪星源   深圳     环境保护  19901210
# 4  000006.SZ  000006  深振业A   深圳     区域地产  19920427

# %% [markdown]
# # 交易日历

# %%
df = pro.trade_cal(exchange='SZSE', start_date='20190101', end_date='20190321')
df.head()
# Out:
#   exchange  cal_date  is_open
# 0     SZSE  20190101        0
# 1     SZSE  20190102        1
# 2     SZSE  20190103        1
# 3     SZSE  20190104        1
# 4     SZSE  20190105        0

# %% [markdown]
# # 沪深股通成份股

# %%
df = pro.hs_const(hs_type='SH') 
df.head()
# Out:
#      ts_code hs_type   in_date out_date is_new
# 0  603818.SH      SH  20160613     None      1
# 1  603108.SH      SH  20161212     None      1
# 2  600507.SH      SH  20141117     None      1
# 3  601377.SH      SH  20141117     None      1
# 4  600309.SH      SH  20141117     None      1

# %% [markdown]
# # 股票曾用名

# %%
df = pro.namechange(ts_code='000002.SZ')
df
# Out:
#      ts_code  name start_date  end_date ann_date change_reason
# 0  000002.SZ   万科A   20061009      None     None            摘G
# 1  000002.SZ  G万科A   20051202  20061008     None          完成股改
# 2  000002.SZ   万科A   20020315  20051201     None            其他
# 3  000002.SZ  深万科A   19910129  20020314     None            其他

# %% [markdown]
# # 上市公司基本信息

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

df = pro.stock_company(exchange='SSE')
df.head()

df_SZSE = pro.stock_company(exchange='SZSE')
df_SZSE.head()
# Out:
#      ts_code exchange chairman manager secretary   reg_capital setup_date  \
# 0  600000.SH      SSE      高国富     刘信义        谢伟  2.935208e+06   19921019
# 1  600001.SH      SSE      李贵阳     张延卿       陈占军  2.816457e+05   19980120
# 2  600002.SH      SSE      张瑞生     王浩水       李风安  1.950000e+05   19980318
# 3  600003.SH      SSE      孙熠嵩     韩增义        戴琦  1.213200e+05   19990721
# 4  600005.SH      SSE      马国强     邹继新       李海涛  1.009378e+06   19971107
#
#   province city                      website  \
# 0       上海  上海市              www.spdb.com.cn
# 1       河北  邯郸市              www.hdgt.com.cn
# 2       山东  淄博市              www.qilu.com.cn
# 3       吉林  长春市  www.northeast-expressway.cn
# 4       湖北  武汉市             www.wisco.com.cn
#
#                                                email  employees
# 0  Yanggp@spdb.com.cn;wur2@spdb.com.cn;bdo@spdb.c...    52551.0
# 1                              hdgt@mail.hgjt.com.cn    17986.0
# ...

# %% [markdown]
# # IPO 新股上市

# %%
df = pro.new_share(start_date="20190101", end_date="20190321")
df
# Out:
#       ts_code sub_code  name  ipo_date issue_date   amount  market_amount  \
# 0   603379.SH   732379  三美股份  20190321        nan   5973.0         1792.0
# 1   002952.SZ   002952  亚世光电  20190318        nan   1826.0         1372.0
# 2   300767.SZ   300767  震安科技  20190314        nan   2000.0         2000.0
# 3   603681.SH   732681  永冠新材  20190314        nan   4165.0         3748.0
# 4   002958.SZ   002958  青农商行  20190313        nan  55556.0        50000.0
# 5   300765.SZ   300765   新诺威  20190313   20190322   5000.0         4500.0
# 6   300766.SZ   300766  每日互动  20190312        nan   4010.0         3609.0
# 7   300763.SZ   300763  锦浪科技  20190308   20190319   2000.0         2000.0
# 8   002951.SZ   002951  金时科技  20190306   20190315   4500.0         4050.0
# 9   300762.SZ   300762  上海瀚讯  20190305   20190314   3336.0         3002.0
# 10  002950.SZ   002950  奥美医疗  20190227   20190311   4800.0         4320.0
# 11  600928.SH   730928  西安银行  20190219   20190301  44444.0        40000.0
# ...
