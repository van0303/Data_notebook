# %%
## 获取 API KEY
from configparser import ConfigParser
cfg = ConfigParser()
cfg.read('./config.ini')
API_KEY = cfg.get('alphavantage', 'API_KEY')

# %% [markdown]
# # Intraday

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key=API_KEY, output_format="pandas")
data, meta_data = ts.get_intraday('GOOGL')

data.head()
# data.index
# data.columns
# data['1. open', '2. high', '3. low']
# fig = plt.figure(figsize=(20,10))


fig, ax = plt.subplots(figsize=(20,10))

# plt.plot(data.loc[:, ['1. open', '2. high', '3. low', '4. close']])
ax.plot(data['1. open'].head(50) , label='open')
ax.plot(data['2. high'].head(50) , label='high')
ax.plot(data['3. low'].head(50) , label='low')
ax.plot(data['4. close'].head(50) , label='close')

# ax.plot(data['1. open'] , label='open')
# ax.plot(data['2. high'] , label='high')
# ax.plot(data['3. low'] , label='low')
# ax.plot(data['4. close'] , label='close')

# ax.xaxis_date()

fig.autofmt_xdate()
# plt.xticks(rotation=15)
plt.legend()
plt.show()
# df = data.loc[:, 0:2]
# df.head()
# meta_data

# %% [markdown]
# # Daily

# %%
df, meta_data = ts.get_daily("GOOGL")
df.head()
data.loc[:, ['1. open', '2. high', '3. low', '4. close']].plot()
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# date
# 2018-11-01  1091.40  1099.90  1077.82   1085.98  2006575.0
# 2018-11-02  1089.00  1098.00  1067.66   1071.49  2172215.0
# 2018-11-05  1072.53  1073.35  1034.00   1055.73  2267870.0
# 2018-11-06  1055.02  1079.82  1053.61   1069.57  1433013.0
# 2018-11-07  1083.49  1109.93  1080.59   1108.24  2169392.0
